# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
pwd
# Out:
# '/content'

# %%
df = pd.read_csv("store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.nunique(axis=1, dropna=True).shape[0]
# Out:
# 17414

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
sns.set_style("whitegrid")

# %%
# season
sns.countplot(x=df.season);

# %%
# is_holiday
sns.countplot(x=df.is_holiday);

# %%
# is_weekend
sns.countplot(x=df.is_weekend);

# %%
# weather_code
sns.countplot(x=df.weather_code);

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.timestamp = pd.to_datetime(df.timestamp)
df.head()
# Out:
#             timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0 2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1 2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2 2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3 2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4 2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df["year_month"] = df.timestamp.apply(lambda x : x.strftime("%Y-%m"))
df["year_month"].head()
# Out:
# 0    2015-01
# 1    2015-01
# 2    2015-01
# 3    2015-01
# 4    2015-01
# Name: year_month, dtype: object

# %%
df["year"] = df.timestamp.apply(lambda x : x.strftime("%Y"))
df["year"].head()
# Out:
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# Name: year, dtype: object

# %%
df["month"] = df.timestamp.apply(lambda x : x.strftime("%-m"))
df["month"].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: month, dtype: object

# %%
df["day_of_month"] = df.timestamp.apply(lambda x : x.strftime("%-d"))
df["day_of_month"].head()
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: day_of_month, dtype: object

# %%
df["day_of_week"] = df.timestamp.apply(lambda x : x.strftime("%-w"))
df["day_of_week"].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: day_of_week, dtype: object

# %%
df["hour"] = df.timestamp.apply(lambda x : x.strftime("%-H"))
df["hour"].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: hour, dtype: object

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2  ...  month  day_of_month  day_of_week  hour
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...      1             4            0     0
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...      1             4            0     1
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...      1             4            0     2
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...      1             4            0     3
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...      1             4            0     4
#
# [5 rows x 16 columns]

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize=(12,9))
sns.heatmap(data=df.corr(),annot=True)
plt.show()

# %%
df.corr()
# Out:
#                    cnt        t1        t2  ...  is_holiday  is_weekend    season
# cnt           1.000000  0.388798  0.369035  ...   -0.051698   -0.096499 -0.116180
# t1            0.388798  1.000000  0.988344  ...   -0.042233   -0.005342 -0.285851
# t2            0.369035  0.988344  1.000000  ...   -0.040051   -0.008510 -0.285900
# hum          -0.462901 -0.447781 -0.403495  ...    0.032068    0.028098  0.290381
# wind_speed    0.116295  0.145471  0.088409  ...   -0.002606    0.011479  0.010305
# weather_code -0.166633 -0.097114 -0.098385  ...    0.012939    0.042362  0.098976
# is_holiday   -0.051698 -0.042233 -0.040051  ...    1.000000   -0.094898 -0.032488
# is_weekend   -0.096499 -0.005342 -0.008510  ...   -0.094898    1.000000  0.001067
# season       -0.116180 -0.285851 -0.285900  ...   -0.032488    0.001067  1.000000
#
# [9 rows x 9 columns]

# %%
# for the target variable
plt.figure(figsize=(2,6))
sns.heatmap(df.corr().loc[:,["cnt"]],annot=True,vmin=-1,vmax=+1);

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
df.corr().loc[:,["cnt"]].sort_values(by="cnt").plot.barh(legend=False,figsize=(10,7));

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(18,6))
sns.lineplot(x="timestamp",y="cnt",data=df);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
df.timestamp = df.year_month

# %%
nev_cnt = df.groupby("timestamp").sum()[["cnt"]]
nev_cnt= nev_cnt.reset_index()
plt.figure(figsize=(20,5))
sns.lineplot(x=nev_cnt.timestamp,y=nev_cnt.cnt);

# %%
# with lineplot
plt.figure(figsize=(10,5))
sns.lineplot(x=df.month,y=df.cnt);

# %%
# with pointplot
plt.figure(figsize=(10,5))
sns.pointplot(x=df.month,y=df.cnt);

# %%
# with barplot
plt.figure(figsize=(10,5))
sns.barplot(x=df.month,y=df.cnt);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(13,5))
sns.lineplot(x=df.hour,y=df.cnt,hue=df.is_holiday);

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(13,5))
sns.lineplot(x=df.hour,y=df.cnt,hue=df.season)

# %%
# with pointplot
plt.figure(figsize=(18,24))
plt.subplot(4,1,1)
sns.pointplot(x=df.hour,y=df.cnt)
plt.subplot(4,1,2)
sns.pointplot(x=df.hour,y=df.cnt,hue=df.is_holiday)
plt.subplot(4,1,3)
sns.pointplot(x=df.hour,y=df.cnt,hue=df.is_weekend)
plt.subplot(4,1,4)
sns.pointplot(x=df.hour,y=df.cnt,hue=df.season);

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
plt.figure(figsize=(13,5))
sns.barplot(x=df.day_of_week,y=df.cnt,hue=df.is_weekend);

# %%
# with pointplot
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
sns.pointplot(x=df.day_of_week,y=df.cnt)
plt.subplot(2,1,2)
sns.pointplot(x=df.day_of_week,y=df.cnt, hue=df.season);

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
plt.figure(figsize=(15,5))
sns.lineplot(x =df.day_of_month, y= df.cnt);

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize=(10,7))
sns.barplot(x=df.year, y=df.cnt);

# %%
# with barplot
plt.figure(figsize=(10,7))
sns.barplot(x=df.season, y=df.cnt)

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# pie chart
label= ["weekday","weekend"]
plt.figure(figsize=(10,7))
plt.pie(x=df.is_weekend.value_counts(),autopct = "%0.2f%%",textprops={"fontsize":15},labels=label);

# %%
# with countplt
fig, ax = plt.subplots()
ax = sns.countplot(x=df.is_weekend)
for p in ax.patches:
    ax.annotate("%"+str(round(p.get_height()/len(df)*100, 1))+" - "+str(p.get_height()), (p.get_x()+0.15, p.get_height()+97), size=15);

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
sns.set_style("whitegrid")

# %%
df.head()
# Out:
#   timestamp  cnt   t1   t2    hum  ...  year  month  day_of_month  day_of_week  hour
# 0   2015-01  182  3.0  2.0   93.0  ...  2015      1             4            0     0
# 1   2015-01  138  3.0  2.5   93.0  ...  2015      1             4            0     1
# 2   2015-01  134  2.5  2.5   96.5  ...  2015      1             4            0     2
# 3   2015-01   72  2.0  2.0  100.0  ...  2015      1             4            0     3
# 4   2015-01   47  2.0  0.0   93.0  ...  2015      1             4            0     4
#
# [5 rows x 16 columns]

# %%
# with countplot
sns.countplot(x=df.weather_code)

# %%
# with catplot
sns.catplot(x="weather_code",data=df,kind="count",col="season");

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
